# %%
# To find what happens in  different channels of a convolution layer of a Convolution Neural Network (CNN).
# 13.1.2022
# Sangeeta Biswas

from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
import cv2
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Model

DIR = 'assignment 12/'

# %%
def display_img(img):
    plt.imshow(img)
    plt.show()
    plt.close()

# %%
def display_channels(chSet, layer_no):	
    plt.figure(figsize = (20, 20))
    plt.suptitle('Layer-' + str(layer_no))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.title('Channel-' + str(i))
        plt.imshow(chSet[0, :, :, i], cmap = 'gray')
        plt.axis('off')
    plt.show()
    plt.close()

# %%
def prepare_data():
    # Load an image
    imgPath = DIR + 'house.jpg' #'Baby.jpeg' #'Rose.jpeg' #'Boat.jpeg' #	
    bgrImg = cv2.imread(imgPath)
    print(bgrImg.shape)

    # Convert the image from BGR into RGB format
    rgbImg = cv2.cvtColor(bgrImg, cv2.COLOR_BGR2RGB)

    # Reshape the image so that it can fit into the model.
    #display_img(rgbImg)
    rgbImg = cv2.resize(rgbImg, (112,112))
    display_img(rgbImg)

    # Expand dimension since the model accepts 4D data.
    print(rgbImg.shape)
    rgbImg = np.expand_dims(rgbImg, axis = 0)
    print(rgbImg.shape)

    # Preprocess image
    rgbImg = preprocess_input(rgbImg)

    return rgbImg

# %%
baseModel = VGG16()
baseModel.summary()
    
# Prepare a new model having the desired layer as the output layer.
layer_number = 10 # *** Change layer number to see different convolution layer's output.
inputs = baseModel.input
outputs = baseModel.layers[layer_number].output
model = Model(inputs, outputs)

# Prepare data.
img = prepare_data()

# Predict output of a specific layer.
outputs = model.predict(img)

# Display what different channls see.
display_channels(outputs, layer_number)
# Out:
# 2022-09-09 20:18:03.613483: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 392.00MiB (rounded to 411041792)requested by op RandomUniform
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2022-09-09 20:18:03.613515: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2022-09-09 20:18:03.613522: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 30, Chunks in use: 30. 7.5KiB allocated for chunks. 7.5KiB in use in bin. 1.6KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613526: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 6, Chunks in use: 6. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 3.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613532: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 10, Chunks in use: 10. 10.2KiB allocated for chunks. 10.2KiB in use in bin. 10.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613536: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 19, Chunks in use: 18. 40.8KiB allocated for chunks. 38.8KiB in use in bin. 36.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613540: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 4, Chunks in use: 4. 24.2KiB allocated for chunks. 24.2KiB in use in bin. 24.2KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613544: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613549: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 2, Chunks in use: 2. 32.0KiB allocated for chunks. 32.0KiB in use in bin. 32.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613552: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613556: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613560: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 4, Chunks in use: 3. 667.5KiB allocated for chunks. 523.5KiB in use in bin. 432.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613565: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 5, Chunks in use: 3. 1.53MiB allocated for chunks. 1008.0KiB in use in bin. 864.0KiB client-requested in use in bin.
# 2022-09-09 20:18:03.613569: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 5, Chunks in use: 3. 2.81MiB allocated for chunks. 1.69MiB in use in bin. 1.69MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613573: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 5, Chunks in use: 3. 6.58MiB allocated for chunks. 4.22MiB in use in bin. 3.38MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613577: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 7, Chunks in use: 5. 15.75MiB allocated for chunks. 11.25MiB in use in bin. 11.25MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613582: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 4, Chunks in use: 4. 20.12MiB allocated for chunks. 20.12MiB in use in bin. 15.75MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613586: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 18, Chunks in use: 16. 175.25MiB allocated for chunks. 157.25MiB in use in bin. 150.62MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613596: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613600: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613605: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 2, Chunks in use: 1. 188.24MiB allocated for chunks. 96.75MiB in use in bin. 64.00MiB client-requested in use in bin.
# 2022-09-09 20:18:03.613609: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2022-09-09 20:18:03.613613: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 3, Chunks in use: 3. 1.18GiB allocated for chunks. 1.18GiB in use in bin. 1.15GiB client-requested in use in bin.
# 2022-09-09 20:18:03.613618: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 392.00MiB was 256.00MiB, Chunk State:
# 2022-09-09 20:18:03.613621: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 1697185792
# 2022-09-09 20:18:03.613629: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000000 of size 1280 next 1
# 2022-09-09 20:18:03.613633: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000500 of size 256 next 2
# 2022-09-09 20:18:03.613637: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000600 of size 256 next 3
# 2022-09-09 20:18:03.613675: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000700 of size 256 next 4
# 2022-09-09 20:18:03.613678: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000800 of size 256 next 5
# 2022-09-09 20:18:03.613681: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000900 of size 256 next 8
# 2022-09-09 20:18:03.613684: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000a00 of size 256 next 9
# 2022-09-09 20:18:03.613687: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000b00 of size 256 next 10
# 2022-09-09 20:18:03.613691: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000c00 of size 256 next 13
# 2022-09-09 20:18:03.613695: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000d00 of size 256 next 14
# 2022-09-09 20:18:03.613699: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a000e00 of size 512 next 17
# 2022-09-09 20:18:03.613703: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001000 of size 256 next 18
# 2022-09-09 20:18:03.613706: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001100 of size 256 next 19
# 2022-09-09 20:18:03.613709: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001200 of size 256 next 70
# 2022-09-09 20:18:03.613713: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001300 of size 256 next 20
# 2022-09-09 20:18:03.613717: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001400 of size 256 next 23
# 2022-09-09 20:18:03.613720: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001500 of size 256 next 24
# 2022-09-09 20:18:03.613723: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001600 of size 1024 next 27
# 2022-09-09 20:18:03.613726: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001a00 of size 256 next 28
# 2022-09-09 20:18:03.613729: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001b00 of size 256 next 29
# 2022-09-09 20:18:03.613734: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a001c00 of size 1024 next 30
# 2022-09-09 20:18:03.613737: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002000 of size 512 next 75
# 2022-09-09 20:18:03.613740: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002200 of size 512 next 33
# 2022-09-09 20:18:03.613743: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002400 of size 256 next 35
# 2022-09-09 20:18:03.613746: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002500 of size 256 next 36
# 2022-09-09 20:18:03.613749: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002600 of size 2048 next 39
# 2022-09-09 20:18:03.613753: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002e00 of size 256 next 40
# 2022-09-09 20:18:03.613756: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a002f00 of size 256 next 41
# 2022-09-09 20:18:03.613760: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a003000 of size 1024 next 81
# 2022-09-09 20:18:03.613764: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a003400 of size 2560 next 6
# 2022-09-09 20:18:03.613768: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a003e00 of size 256 next 69
# 2022-09-09 20:18:03.613772: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a003f00 of size 512 next 15
# 2022-09-09 20:18:03.613776: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a004100 of size 1024 next 26
# 2022-09-09 20:18:03.613780: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a004500 of size 2048 next 37
# 2022-09-09 20:18:03.613783: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a004d00 of size 3072 next 7
# 2022-09-09 20:18:03.613788: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a005900 of size 2048 next 42
# 2022-09-09 20:18:03.613791: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a006100 of size 2048 next 46
# 2022-09-09 20:18:03.613795: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a006900 of size 2048 next 48
# 2022-09-09 20:18:03.613798: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a007100 of size 1024 next 80
# 2022-09-09 20:18:03.613803: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a007500 of size 1024 next 50
# 2022-09-09 20:18:03.613806: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a007900 of size 256 next 52
# 2022-09-09 20:18:03.613810: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a007a00 of size 256 next 53
# 2022-09-09 20:18:03.613814: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a007b00 of size 16384 next 54
# 2022-09-09 20:18:03.613817: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00bb00 of size 256 next 57
# 2022-09-09 20:18:03.613820: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00bc00 of size 256 next 58
# 2022-09-09 20:18:03.613823: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00bd00 of size 4096 next 51
# 2022-09-09 20:18:03.613827: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00cd00 of size 2048 next 115
# 2022-09-09 20:18:03.613831: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00d500 of size 2048 next 117
# 2022-09-09 20:18:03.613835: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00dd00 of size 2048 next 119
# 2022-09-09 20:18:03.613838: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00e500 of size 2048 next 121
# 2022-09-09 20:18:03.613841: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00ed00 of size 2048 next 123
# 2022-09-09 20:18:03.613844: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f201a00f500 of size 2048 next 59
# 2022-09-09 20:18:03.613849: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00fd00 of size 256 next 62
# 2022-09-09 20:18:03.613853: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00fe00 of size 256 next 63
# 2022-09-09 20:18:03.613856: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a00ff00 of size 2048 next 86
# 2022-09-09 20:18:03.613860: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a010700 of size 2048 next 66
# 2022-09-09 20:18:03.613864: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a010f00 of size 256 next 67
# 2022-09-09 20:18:03.613868: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a011000 of size 6912 next 68
# 2022-09-09 20:18:03.613872: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a012b00 of size 241152 next 12
# 2022-09-09 20:18:03.613877: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a04d900 of size 442368 next 16
# 2022-09-09 20:18:03.613880: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a0b9900 of size 2064384 next 21
# 2022-09-09 20:18:03.613884: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a2b1900 of size 589824 next 11
# 2022-09-09 20:18:03.613888: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a341900 of size 4718592 next 31
# 2022-09-09 20:18:03.613892: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c1900 of size 16384 next 56
# 2022-09-09 20:18:03.613895: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c5900 of size 2048 next 89
# 2022-09-09 20:18:03.613899: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c6100 of size 2048 next 92
# 2022-09-09 20:18:03.613902: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c6900 of size 2816 next 32
# 2022-09-09 20:18:03.613905: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c7400 of size 6912 next 22
# 2022-09-09 20:18:03.613908: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c8f00 of size 256 next 98
# 2022-09-09 20:18:03.613912: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c9000 of size 512 next 100
# 2022-09-09 20:18:03.613915: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c9200 of size 512 next 103
# 2022-09-09 20:18:03.613918: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c9400 of size 1024 next 107
# 2022-09-09 20:18:03.613921: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c9800 of size 1024 next 108
# 2022-09-09 20:18:03.613925: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7c9c00 of size 1024 next 111
# 2022-09-09 20:18:03.613929: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7ca000 of size 2560 next 96
# 2022-09-09 20:18:03.613932: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a7caa00 of size 6912 next 97
# 2022-09-09 20:18:03.613935: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f201a7cc500 of size 281088 next 72
# 2022-09-09 20:18:03.613939: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a810f00 of size 147456 next 71
# 2022-09-09 20:18:03.613942: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f201a834f00 of size 147456 next 99
# 2022-09-09 20:18:03.613946: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a858f00 of size 147456 next 73
# 2022-09-09 20:18:03.613949: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f201a87cf00 of size 294912 next 74
# 2022-09-09 20:18:03.613952: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7
I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 6 Chunks of size 512 totalling 3.0KiB
# 2022-09-09 20:18:03.614140: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 1024 totalling 9.0KiB
# 2022-09-09 20:18:03.614145: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 1280 totalling 1.2KiB
# 2022-09-09 20:18:03.614150: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 14 Chunks of size 2048 totalling 28.0KiB
# 2022-09-09 20:18:03.614156: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 2560 totalling 5.0KiB
# 2022-09-09 20:18:03.614161: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2816 totalling 2.8KiB
# 2022-09-09 20:18:03.614164: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 3072 totalling 3.0KiB
# 2022-09-09 20:18:03.614169: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 4096 totalling 4.0KiB
# 2022-09-09 20:18:03.614175: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 6912 totalling 20.2KiB
# 2022-09-09 20:18:03.614181: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 16384 totalling 32.0KiB
# 2022-09-09 20:18:03.614188: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 147456 totalling 288.0KiB
# 2022-09-09 20:18:03.614193: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 241152 totalling 235.5KiB
# 2022-09-09 20:18:03.614200: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 294912 totalling 576.0KiB
# 2022-09-09 20:18:03.614207: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 442368 totalling 432.0KiB
# 2022-09-09 20:18:03.614212: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 3 Chunks of size 589824 totalling 1.69MiB
# 2022-09-09 20:18:03.614217: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 1179648 totalling 2.25MiB
# 2022-09-09 20:18:03.614222: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 2064384 totalling 1.97MiB
# 2022-09-09 20:18:03.614227: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 5 Chunks of size 2359296 totalling 11.25MiB
# 2022-09-09 20:18:03.614232: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 4587520 totalling 4.38MiB
# 2022-09-09 20:18:03.614236: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 4718592 totalling 9.00MiB
# 2022-09-09 20:18:03.614241: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 7077888 totalling 6.75MiB
# 2022-09-09 20:18:03.614247: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 14 Chunks of size 9437184 totalling 126.00MiB
# 2022-09-09 20:18:03.614252: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 16384000 totalling 31.25MiB
# 2022-09-09 20:18:03.614258: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 101449728 totalling 96.75MiB
# 2022-09-09 20:18:03.614263: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 2 Chunks of size 411041792 totalling 784.00MiB
# 2022-09-09 20:18:03.614268: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 444071936 totalling 423.50MiB
# 2022-09-09 20:18:03.614273: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 1.46GiB
# 2022-09-09 20:18:03.614277: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 1697185792 memory_limit_: 1697185792 available bytes: 0 curr_region_allocation_bytes_: 3394371584
# 2022-09-09 20:18:03.614287: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                      1697185792
# InUse:                      1573272832
# MaxInUse:                   1592145152
# NumAllocs:                         270
# MaxAllocSize:                444071936
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2022-09-09 20:18:03.614299: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ************************************************************************************x**********_____
# 2022-09-09 20:18:03.765272: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at random_op.cc:74 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[25088,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# /tmp/ipykernel_147934/925233538.py in <module>
# ----> 1 baseModel = VGG16()
#       2 baseModel.summary()
#       3
#       4 # Prepare a new model having the desired layer as the output layer.
#       5 layer_number = 10 # *** Change layer number to see different convolution layer's output.
#
# ~/anaconda3/envs/deepenv/lib/python3.9/site-packages/keras/applications/vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     186     # Classification block
#     187     x = layers.Flatten(name='flatten')(x)
# --> 188     x = layers.Dense(4096, activation='relu', name='fc1')(x)
#     189     x = layers.Dense(4096, activation='relu', name='fc2')(x)
#     190
#
# ~/anaconda3/envs/deepenv/lib/python3.9/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~/anaconda3/envs/deepenv/lib/python3.9/site-packages/keras/backend.py in random_uniform(self, shape, minval, maxval, dtype)
#    1918       return self._generator.uniform(
#    1919           shape=shape, minval=minval, maxval=maxval, dtype=dtype)
# -> 1920     return tf.random.uniform(
#    1921         shape=shape, minval=minval, maxval=maxval, dtype=dtype,
#    1922         seed=self.make_legacy_seed())
#
# ResourceExhaustedError: OOM when allocating tensor with shape[25088,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:RandomUniform]
